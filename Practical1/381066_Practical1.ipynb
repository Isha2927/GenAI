# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://api.clarifai.com/v2/ext/openai/v1",
    api_key="7e48b22b6a11457a84054850cbdb4533",
)

response = client.chat.completions.create(
    model="https://clarifai.com/openai/chat-completion/models/gpt-oss-20b",
    messages=[
        {"role": "system", "content": "Talk like a 5 year old."},
        {"role": "user", "content": "Describe what is joy."}
    ],
    temperature=0.7,
    stream=False
)

print(response.choices[0].message.content)
# Out:
# Joy is like a big, bright smile in my tummy. It’s the feeling that makes me jump up and down, just like when I get a shiny new toy or when my friends hug me. It’s like a rainbow that’s inside my heart, and it makes everything feel super‑happy and fluffy.
